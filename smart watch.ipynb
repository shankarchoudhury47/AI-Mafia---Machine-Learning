# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_x = pd.read_csv('./data/Linear_X_Train.csv')
train_y = pd.read_csv('./data/Linear_y_Train.csv')
test_x=pd.read_csv('./data/Linear_X_Test.csv')

x = train_x.values.reshape((-1,1))
y = train_y.values.reshape((-1,1))
x1= test_x.values

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
output = model.predict(x1)
bias = model.intercept_
coeff = model.coef_

print(bias)
print(coeff)
# Out:
# [3.72798828]
# [[80.54363185]]

# %%
model.score(x,y)
# Out:
# 0.9709612233822353

# %%
plt.scatter(x,y,label='data')
plt.plot(x1,output,color='orange',label='prediction')
plt.legend()
plt.show()
